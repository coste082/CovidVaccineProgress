# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('country_vaccinations.csv')

# %%
data['date'] = pd.to_datetime(data['date'])
data = data.set_index('date')

# %%
data.head()
# Out:
#             country iso_code  total_vaccinations  people_vaccinated  \
# date
# 2021-01-10  Albania      ALB                 0.0                0.0
# 2021-01-11  Albania      ALB                 NaN                NaN
# 2021-01-12  Albania      ALB               128.0              128.0
# 2021-01-13  Albania      ALB               188.0              188.0
# 2021-01-14  Albania      ALB               266.0              266.0
#
#             people_fully_vaccinated  daily_vaccinations_raw  \
# date
# 2021-01-10                      NaN                     NaN
# 2021-01-11                      NaN                     NaN
# 2021-01-12                      NaN                     NaN
# 2021-01-13                      NaN                    60.0
# 2021-01-14                      NaN                    78.0
#
#             daily_vaccinations  total_vaccinations_per_hundred  \
# date
# 2021-01-10                 NaN                            0.00
# ...

# %%
fig, ax = plt.subplots(figsize=(20,20))
for i,t in data.groupby('country'):
    #t= t.set_index('date')
    t['people_fully_vaccinated_per_hundred'] = t['people_fully_vaccinated_per_hundred'].interpolate(method='time')
    t.head()
    ax.plot(t['people_fully_vaccinated_per_hundred'],label=i)
    ax.annotate(name, xy=(1,t['people_fully_vaccinated_per_hundred'][-1]), xytext=(6,0), color=line.get_color(), 
                size=14, va="center")
#ax.legend()
plt.show()
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ...

# %%
for i,t in data.groupby('country'):
    print(t['country'][0],t['people_fully_vaccinated_per_hundred'][-1])
# Out:
# Albania 0.02
# Algeria nan
# Andorra nan
# Anguilla nan
# Argentina 0.53
# Austria 1.6
# Azerbaijan nan
# Bahrain nan
# Bangladesh nan
# Belgium 1.64
# Bermuda 2.57
# Bolivia nan
# Brazil 0.1
# Bulgaria 0.31
# Cambodia nan
# Canada nan
# Cayman Islands 9.69
# Chile 0.29
# China nan
# Costa Rica 0.84
# Croatia 1.29
# Cyprus 1.6
# Czechia 1.53
# Denmark 2.9
# Ecuador nan
# Egypt nan
# England 0.87
# Estonia 1.68
# Faeroe Islands 2.5
# Finland 1.21
# France 0.94
# Germany 1.68
# Gibraltar 29.84
# Greece 1.62
# Greenland nan
# Guernsey nan
# Hungary 1.34
# Iceland 1.69
# India nan
# Indonesia 0.18
# Iran nan
# Ireland 1.82
# Isle of Man 3.91
# Israel 30.17
# Italy 2.13
# Jersey 3.14
# Kuwait nan
# Latvia 0.86
# Liechtenstein nan
# Lithuania 2.0
# Luxembourg 0.9
# Maldives nan
# Malta 3.68
# Mauritius nan
# Mexico 0.07
# Monaco nan
# Morocco nan
# Myanmar nan
# Nepal nan
# Netherlands nan
# Northern Cyprus nan
# Northern Ireland 1.53
# Norway 1.3
# Oman 0.24
# Pakistan nan
# Panama nan
# ...
